# %% [markdown]
# Let A = [[2,-1],
#         [0,3]]
#
# Let B = [[1,4],
#          [-2,5]]
#
# Let scalar (c = 2), (d = 3)
#
#
# * 1. Compute the following: (cA), (dB), and (c + d)A
# * 2. Using the results gotten, Verify the scalar multiplication properties.
# * 3. Find the transpose of both matrices:
# * 4. Check if (A) and (B) are invertible by computing their determinants. If they are invertible, find: A-1 and B-1.

# %% [markdown]
# ### 1. Compute the following: (cA), (dB), and (C+d)A
# ```
#
# A = [2   -1]    [0  3]
#
#
# B = [1  4]      [-2 5]
#
# scalar c = 2, d = 3
#
#
# cA = [[2x2] [2x(-1)],
#
#       [2x0] [2x3]]
#
#
# cA = [[4]   [-2],
#
#       [0]   [6]]
#
#
# cA = [[4    -2],
#
#       [0    6]]

# %% [markdown]
# #### dB
# ```
#  dB = [[3x1] [3x4],
#
#       [3x(-2)] [3x5]]
#
# dB = [[3    12],
#
#       [-6   15]]

# %% [markdown]
# ### (c+d)A
# ```
#
# (c+d)A = cA + dA
#
# (c+d)A =    (2+3)[2   -1]    [0  3]
#        = [[5x2], [5x(-1)],
#           [5x0], [5x3]]
#        =  [[10, -5],
#            [0, 15]]

# %% [markdown]
# ## 2. Using the result gotten, verify the scalar multiplication properties.
# ```
# Let A = [[2,-1],
#         [0,3]]
#
# Let B = [[1,4],
#          [-2,5]]
#
# Let scalar (c = 2), (d = 3)
# Associativity of scalar Matrix:
#
# (c.d)A = c.(dA)
# Calculating (c.d)A:
#    = (2x3)[[2,-1][0,3]]
#    = [6x2,6x-1][6x0,6x3]
#    =[12,-1][0,18]
#
# Distributivity over matrix addition:
#
# c(A+B) = cA + cB
#       = 2[[2,-1][0,3] +
#           [1,4][-2,5]]
#
#       = 2[[2+1,-1+4]
#           [0+-2, 3+5]]
#       = 2[[3,-3],
#           [-2,8]]
#       = [6,-6],[-4, -8]
#
# Distributivity over scalar addition:
# (c+d)A = cA + dA
# (c+d)A = (2+3)x [[2,-1]
#                  [0,3]]
#
#       =[5x2, 5x-1] [5x0, 5x3]
#       =[10, -5] [0, 15]

# %% [markdown]
# ## 3. Find the transpose of both matrices:
# ```
#
# A = [[2 -1],
#      [0, 3]]
#
# The transpose of A = [[2, 0],
#                       [-1, 3]]
#
# B = [[1, 4],
#      [-2, 5]]
#
# The transpose of B = [[1, -2],
#                       [4, 5]]

# %% [markdown]
# ### 4. Check if (A) and (B) are invertible by computing their determinants. If they are invertible, find: A inverse and B inverse.
# Finding the inverse of A:
#
# A = [[2 1],
#      [0 3]]
#
#
# ΔA = ad-bc
#    = 2(3) - 1(0)
#    = 6 - 0
#    = 6
#
# A^-1 = 1/ΔA = 1/6 X [[3 1],  = [[3/6 1/6], =  [[1/2, 1/6],
#                      [0 2]]      [0 2/6] ]        [0, 1/2]]
#
# The inverse of A = [[1/2], [1/6],
#                     [0], [1/2]]
#
# The inverse of B =  [[1,4],
#                      [-2,5]]
#
#               ΔB =  ad - bc
#                  =  1(5)- 4(-2)
#                  = 5-(-8)
#                  = 5+8
#                  = 13
# B^-1 = 1/ΔB = 1/13 X [[1,4],[-2,5]] = [[1/13, 4/13], [-2/13, 5/13]]
#
# The inverse of B is  [[1/13, 4/13], [-2/13, 5/13]]
